# %% [markdown]
# <a href="https://colab.research.google.com/github/DataMinati/100-Super-Notebooks/blob/main/solar_power_generation_forecast_using_different_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline 

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Importing Power Generation & Weather Sensor Data

# %%
generation_data = pd.read_csv('/content/Plant_1_Generation_Data.csv')
weather_data = pd.read_csv('/content/Plant_1_Weather_Sensor_Data.csv')

# %%
generation_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68778 entries, 0 to 68777
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE_TIME    68778 non-null  object
#  1   PLANT_ID     68778 non-null  int64
#  2   SOURCE_KEY   68778 non-null  object
#  3   DC_POWER     68778 non-null  float64
#  4   AC_POWER     68778 non-null  float64
#  5   DAILY_YIELD  68778 non-null  float64
#  6   TOTAL_YIELD  68778 non-null  float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 3.7+ MB

# %%
generation_data.sample(5).style.set_properties(
    **{
        'background-color': 'orange',
        'color': 'black',
        'border-color': 'darkblack'
    })
# Out:
# <style type="text/css">
# #T_56e49_row0_col0, #T_56e49_row0_col1, #T_56e49_row0_col2, #T_56e49_row0_col3, #T_56e49_row0_col4, #T_56e49_row0_col5, #T_56e49_row0_col6, #T_56e49_row1_col0, #T_56e49_row1_col1, #T_56e49_row1_col2, #T_56e49_row1_col3, #T_56e49_row1_col4, #T_56e49_row1_col5, #T_56e49_row1_col6, #T_56e49_row2_col0, #T_56e49_row2_col1, #T_56e49_row2_col2, #T_56e49_row2_col3, #T_56e49_row2_col4, #T_56e49_row2_col5, #T_56e49_row2_col6, #T_56e49_row3_col0, #T_56e49_row3_col1, #T_56e49_row3_col2, #T_56e49_row3_col3, #T_56e49_row3_col4, #T_56e49_row3_col5, #T_56e49_row3_col6, #T_56e49_row4_col0, #T_56e49_row4_col1, #T_56e49_row4_col2, #T_56e49_row4_col3, #T_56e49_row4_col4, #T_56e49_row4_col5, #T_56e49_row4_col6 {
#   background-color: orange;
#   color: black;
#   border-color: darkblack;
# }
# </style>
# <table id="T_56e49_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >DATE_TIME</th>
#       <th class="col_heading level0 col1" >PLANT_ID</th>
#       <th class="col_heading level0 col2" >SOURCE_KEY</th>
#       <th class="col_heading level0 col3" >DC_POWER</th>
#       <th class="col_heading level0 col4" >AC_POWER</th>
#       <th class="col_heading level0 col5" >DAILY_YIELD</th>
#       <th class="col_heading level0 col6" >TOTAL_YIELD</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56e49_level0_row0" class="row_heading level0 row0" >37574</th>
#       <td id="T_56e49_row0_col0" class="data row0 col0" >03-06-2020 02:45</td>
#       <td id="T_56e49_row0_col1" class="data row0 col1" >4135001</td>
#       <td id="T_56e49_row0_col2" class="data row0 col2" >zBIq5rxdHJRwDNY</td>
#       <td id="T_56e49_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_56e49_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_56e49_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_56e49_row0_col6" class="data row0 col6" >6476454.000000</td>
#     </tr>
#     <tr>
#       <th id="T_56e49_level0_row1" class="row_heading level0 row1" >13277</th>
#       <td id="T_56e49_row1_col0" class="data row1 col0" >22-05-2020 01:30</td>
#       <td id="T_56e49_row1_col1" class="data row1 col1" >4135001</td>
#       <td id="T_56e49_row1_col2" class="data row1 col2" >7JYdWkrLSPkdwr4</td>
#       <td id="T_56e49_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_56e49_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_56e49_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_56e49_row1_col6" class="data row1 col6" >7651635.000000</td>
#     </tr>
#     <tr>
#       <th id="T_56e49_level0_row2" class="row_heading level0 row2" >15506</th>
#       <td id="T_56e49_row2_col0" class="data row2 col0" >23-05-2020 03:45</td>
#       <td id="T_56e49_row2_col1" class="data row2 col1" >4135001</td>
#       <td id="T_56e49_row2_col2" class="data row2 col2" >WRmjgnKYAwPKWDb</td>
#       <td id="T_56e49_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_56e49_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_56e49_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_56e49_row2_col6" class="data row2 col6" >7084595.000000</td>
#     </tr>
#     <tr>
#       <th id="T_56e49_level0_row3" class="row_heading level0 row3" >7898</th>
#       <td id="T_56e49_row3_col0" class="data row3 col0" >18-05-2020 21:30</td>
#       <td id="T_56e49_row3_col1" class="data row3 col1" >4135001</td>
#       <td id="T_56e49_row3_col2" class="data row3 col2" >WRmjgnKYAwPKWDb</td>
#       <td id="T_56e49_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_56e49_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_56e49_row3_col5" class="data row3 col5" >5348.000000</td>
#       <td id="T_56e49_row3_col6" class="data row3 col6" >7054452.000000</td>
#     </tr>
#     <tr>
#       <th id="T_56e49_level0_row4" class="row_heading level0 row4" >15212</th>
#       <td id="T_56e49_row4_col0" class="data row4 col0" >23-05-2020 00:15</td>
#       <td id="T_56e49_row4_col1" class="data row4 col1" >4135001</td>
#       <td id="T_56e49_row4_col2" class="data row4 col2" >zBIq5rxdHJRwDNY</td>
#       <td id="T_56e49_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_56e49_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_56e49_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_56e49_row4_col6" class="data row4 col6" >6395807.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
weather_data.sample(5).style.set_properties(
    **{
        'background-color': 'olive',
        'color': 'Black',
        'border-color': 'darkblack'
    })
# Out:
# <style type="text/css">
# #T_99bbc_row0_col0, #T_99bbc_row0_col1, #T_99bbc_row0_col2, #T_99bbc_row0_col3, #T_99bbc_row0_col4, #T_99bbc_row0_col5, #T_99bbc_row1_col0, #T_99bbc_row1_col1, #T_99bbc_row1_col2, #T_99bbc_row1_col3, #T_99bbc_row1_col4, #T_99bbc_row1_col5, #T_99bbc_row2_col0, #T_99bbc_row2_col1, #T_99bbc_row2_col2, #T_99bbc_row2_col3, #T_99bbc_row2_col4, #T_99bbc_row2_col5, #T_99bbc_row3_col0, #T_99bbc_row3_col1, #T_99bbc_row3_col2, #T_99bbc_row3_col3, #T_99bbc_row3_col4, #T_99bbc_row3_col5, #T_99bbc_row4_col0, #T_99bbc_row4_col1, #T_99bbc_row4_col2, #T_99bbc_row4_col3, #T_99bbc_row4_col4, #T_99bbc_row4_col5 {
#   background-color: olive;
#   color: Black;
#   border-color: darkblack;
# }
# </style>
# <table id="T_99bbc_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >DATE_TIME</th>
#       <th class="col_heading level0 col1" >PLANT_ID</th>
#       <th class="col_heading level0 col2" >SOURCE_KEY</th>
#       <th class="col_heading level0 col3" >AMBIENT_TEMPERATURE</th>
#       <th class="col_heading level0 col4" >MODULE_TEMPERATURE</th>
#       <th class="col_heading level0 col5" >IRRADIATION</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99bbc_level0_row0" class="row_heading level0 row0" >300</th>
#       <td id="T_99bbc_row0_col0" class="data row0 col0" >2020-05-18 05:45:00</td>
#       <td id="T_99bbc_row0_col1" class="data row0 col1" >4135001</td>
#       <td id="T_99bbc_row0_col2" class="data row0 col2" >HmiyD2TTLFNqkNe</td>
#       <td id="T_99bbc_row0_col3" class="data row0 col3" >21.265387</td>
#       <td id="T_99bbc_row0_col4" class="data row0 col4" >19.976233</td>
#       <td id="T_99bbc_row0_col5" class="data row0 col5" >0.000520</td>
#     </tr>
#     <tr>
#       <th id="T_99bbc_level0_row1" class="row_heading level0 row1" >1114</th>
#       <td id="T_99bbc_row1_col0" class="data row1 col0" >2020-05-27 06:30:00</td>
#       <td id="T_99bbc_row1_col1" class="data row1 col1" >4135001</td>
#       <td id="T_99bbc_row1_col2" class="data row1 col2" >HmiyD2TTLFNqkNe</td>
#       <td id="T_99bbc_row1_col3" class="data row1 col3" >23.340881</td>
#       <td id="T_99bbc_row1_col4" class="data row1 col4" >22.568992</td>
#       <td id="T_99bbc_row1_col5" class="data row1 col5" >0.060636</td>
#     </tr>
#     <tr>
#       <th id="T_99bbc_level0_row2" class="row_heading level0 row2" >696</th>
#       <td id="T_99bbc_row2_col0" class="data row2 col0" >2020-05-22 20:30:00</td>
#       <td id="T_99bbc_row2_col1" class="data row2 col1" >4135001</td>
#       <td id="T_99bbc_row2_col2" class="data row2 col2" >HmiyD2TTLFNqkNe</td>
#       <td id="T_99bbc_row2_col3" class="data row2 col3" >26.645117</td>
#       <td id="T_99bbc_row2_col4" class="data row2 col4" >24.928733</td>
#       <td id="T_99bbc_row2_col5" class="data row2 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_99bbc_level0_row3" class="row_heading level0 row3" >1186</th>
#       <td id="T_99bbc_row3_col0" class="data row3 col0" >2020-05-28 00:30:00</td>
#       <td id="T_99bbc_row3_col1" class="data row3 col1" >4135001</td>
#       <td id="T_99bbc_row3_col2" class="data row3 col2" >HmiyD2TTLFNqkNe</td>
#       <td id="T_99bbc_row3_col3" class="data row3 col3" >23.145158</td>
#       <td id="T_99bbc_row3_col4" class="data row3 col4" >21.689502</td>
#       <td id="T_99bbc_row3_col5" class="data row3 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_99bbc_level0_row4" class="row_heading level0 row4" >2334</th>
#       <td id="T_99bbc_row4_col0" class="data row4 col0" >2020-06-09 04:00:00</td>
#       <td id="T_99bbc_row4_col1" class="data row4 col1" >4135001</td>
#       <td id="T_99bbc_row4_col2" class="data row4 col2" >HmiyD2TTLFNqkNe</td>
#       <td id="T_99bbc_row4_col3" class="data row4 col3" >21.167344</td>
#       <td id="T_99bbc_row4_col4" class="data row4 col4" >19.384184</td>
#       <td id="T_99bbc_row4_col5" class="data row4 col5" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Adjust datetime format

# %%
generation_data['DATE'] = pd.to_datetime(generation_data['DATE_TIME']).dt.date
generation_data['TIME'] = pd.to_datetime(generation_data['DATE_TIME']).dt.time
weather_data['DATE'] = pd.to_datetime(weather_data['DATE_TIME']).dt.date
weather_data['TIME'] = pd.to_datetime(weather_data['DATE_TIME']).dt.time

# %%
generation_data.head()
# Out:
#           DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 0  15-05-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 1  15-05-2020 00:00   4135001  1IF53ai7Xc0U56Y       0.0       0.0
# 2  15-05-2020 00:00   4135001  3PZuoBAID5Wc2HD       0.0       0.0
# 3  15-05-2020 00:00   4135001  7JYdWkrLSPkdwr4       0.0       0.0
# 4  15-05-2020 00:00   4135001  McdE0feGgRqW7Ca       0.0       0.0
#
#    DAILY_YIELD  TOTAL_YIELD        DATE      TIME
# 0          0.0    6259559.0  2020-05-15  00:00:00
# 1          0.0    6183645.0  2020-05-15  00:00:00
# 2          0.0    6987759.0  2020-05-15  00:00:00
# 3          0.0    7602960.0  2020-05-15  00:00:00
# 4          0.0    7158964.0  2020-05-15  00:00:00

# %%
weather_data.head()
# Out:
#              DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 0  2020-05-15 00:00:00   4135001  HmiyD2TTLFNqkNe            25.184316
# 1  2020-05-15 00:15:00   4135001  HmiyD2TTLFNqkNe            25.084589
# 2  2020-05-15 00:30:00   4135001  HmiyD2TTLFNqkNe            24.935753
# 3  2020-05-15 00:45:00   4135001  HmiyD2TTLFNqkNe            24.846130
# 4  2020-05-15 01:00:00   4135001  HmiyD2TTLFNqkNe            24.621525
#
#    MODULE_TEMPERATURE  IRRADIATION        DATE      TIME
# 0           22.857507          0.0  2020-05-15  00:00:00
# 1           22.761668          0.0  2020-05-15  00:15:00
# 2           22.592306          0.0  2020-05-15  00:30:00
# 3           22.360852          0.0  2020-05-15  00:45:00
# 4           22.165423          0.0  2020-05-15  01:00:00

# %%
del generation_data['DATE_TIME']
del weather_data['DATE_TIME']

# %%
generation_data['DATE_TIME'] = generation_data["DATE"].astype(str) + " " + generation_data["TIME"].astype(str)

# %%
weather_data['DATE_TIME'] = weather_data["DATE"].astype(str) + " " + weather_data["TIME"].astype(str)

# %%
generation_data['DATE_TIME']
# Out:
# 0        2020-05-15 00:00:00
# 1        2020-05-15 00:00:00
# 2        2020-05-15 00:00:00
# 3        2020-05-15 00:00:00
# 4        2020-05-15 00:00:00
#                 ...
# 68773    2020-06-17 23:45:00
# 68774    2020-06-17 23:45:00
# 68775    2020-06-17 23:45:00
# 68776    2020-06-17 23:45:00
# 68777    2020-06-17 23:45:00
# Name: DATE_TIME, Length: 68778, dtype: object

# %%
gd1=generation_data
del gd1['DATE']
del gd1['TIME']
gd1
# Out:
#        PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  DAILY_YIELD  \
# 0       4135001  1BY6WEcLGh8j5v7       0.0       0.0        0.000
# 1       4135001  1IF53ai7Xc0U56Y       0.0       0.0        0.000
# 2       4135001  3PZuoBAID5Wc2HD       0.0       0.0        0.000
# 3       4135001  7JYdWkrLSPkdwr4       0.0       0.0        0.000
# 4       4135001  McdE0feGgRqW7Ca       0.0       0.0        0.000
# ...         ...              ...       ...       ...          ...
# 68773   4135001  uHbuxQJl8lW7ozc       0.0       0.0     5967.000
# 68774   4135001  wCURE6d3bPkepu2       0.0       0.0     5147.625
# 68775   4135001  z9Y9gH1T5YWrNuG       0.0       0.0     5819.000
# 68776   4135001  zBIq5rxdHJRwDNY       0.0       0.0     5817.000
# 68777   4135001  zVJPv84UY57bAof       0.0       0.0     5910.000
#
#        TOTAL_YIELD            DATE_TIME
# 0        6259559.0  2020-05-15 00:00:00
# 1        6183645.0  2020-05-15 00:00:00
# 2        6987759.0  2020-05-15 00:00:00
# 3        7602960.0  2020-05-15 00:00:00
# 4        7158964.0  2020-05-15 00:00:00
# ...            ...                  ...
# 68773    7287002.0  2020-06-17 23:45:00
# 68774    7028601.0  2020-06-17 23:45:00
# 68775    7251204.0  2020-06-17 23:45:00
# 68776    6583369.0  2020-06-17 23:45:00
# 68777    7363272.0  2020-06-17 23:45:00
#
# [68778 rows x 7 columns]

# %%
gd1['DATE_TIME'] =  pd.to_datetime(gd1['DATE_TIME'], format='%Y-%m-%d')

# %%
gd1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68778 entries, 0 to 68777
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PLANT_ID     68778 non-null  int64
#  1   SOURCE_KEY   68778 non-null  object
#  2   DC_POWER     68778 non-null  float64
#  3   AC_POWER     68778 non-null  float64
#  4   DAILY_YIELD  68778 non-null  float64
#  5   TOTAL_YIELD  68778 non-null  float64
#  6   DATE_TIME    68778 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 3.7+ MB

# %%
wd1=weather_data
del wd1['DATE']
del wd1['TIME']
wd1
# Out:
#       PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  \
# 0      4135001  HmiyD2TTLFNqkNe            25.184316           22.857507
# 1      4135001  HmiyD2TTLFNqkNe            25.084589           22.761668
# 2      4135001  HmiyD2TTLFNqkNe            24.935753           22.592306
# 3      4135001  HmiyD2TTLFNqkNe            24.846130           22.360852
# 4      4135001  HmiyD2TTLFNqkNe            24.621525           22.165423
# ...        ...              ...                  ...                 ...
# 3177   4135001  HmiyD2TTLFNqkNe            22.150570           21.480377
# 3178   4135001  HmiyD2TTLFNqkNe            22.129816           21.389024
# 3179   4135001  HmiyD2TTLFNqkNe            22.008275           20.709211
# 3180   4135001  HmiyD2TTLFNqkNe            21.969495           20.734963
# 3181   4135001  HmiyD2TTLFNqkNe            21.909288           20.427972
#
#       IRRADIATION            DATE_TIME
# 0             0.0  2020-05-15 00:00:00
# 1             0.0  2020-05-15 00:15:00
# 2             0.0  2020-05-15 00:30:00
# 3             0.0  2020-05-15 00:45:00
# 4             0.0  2020-05-15 01:00:00
# ...           ...                  ...
# 3177          0.0  2020-06-17 22:45:00
# 3178          0.0  2020-06-17 23:00:00
# 3179          0.0  2020-06-17 23:15:00
# 3180          0.0  2020-06-17 23:30:00
# 3181          0.0  2020-06-17 23:45:00
#
# [3182 rows x 6 columns]

# %% [markdown]
# # Converting object date_time into daytime stamping

# %%
wd1['DATE_TIME'] =  pd.to_datetime(wd1['DATE_TIME'], format='%Y-%m-%d')

# %%
wd1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3182 entries, 0 to 3181
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   PLANT_ID             3182 non-null   int64
#  1   SOURCE_KEY           3182 non-null   object
#  2   AMBIENT_TEMPERATURE  3182 non-null   float64
#  3   MODULE_TEMPERATURE   3182 non-null   float64
#  4   IRRADIATION          3182 non-null   float64
#  5   DATE_TIME            3182 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), int64(1), object(1)
# memory usage: 149.3+ KB

# %% [markdown]
# # Merging generation data and weather sensor data

# %%
df_solar = pd.merge(gd1.drop(columns = ['PLANT_ID']), wd1.drop(columns = ['PLANT_ID', 'SOURCE_KEY']), on='DATE_TIME')
df_solar.sample(5).style.background_gradient(cmap='cool')
# Out:
# <style type="text/css">
# #T_7b61c_row0_col1, #T_7b61c_row0_col2, #T_7b61c_row0_col8, #T_7b61c_row1_col6, #T_7b61c_row2_col1, #T_7b61c_row2_col2, #T_7b61c_row2_col3, #T_7b61c_row2_col6, #T_7b61c_row2_col7, #T_7b61c_row2_col8, #T_7b61c_row4_col4 {
#   background-color: #00ffff;
#   color: #000000;
# }
# #T_7b61c_row0_col3, #T_7b61c_row0_col4, #T_7b61c_row4_col1, #T_7b61c_row4_col2, #T_7b61c_row4_col6, #T_7b61c_row4_col7, #T_7b61c_row4_col8 {
#   background-color: #ff00ff;
#   color: #f1f1f1;
# }
# #T_7b61c_row0_col6 {
#   background-color: #7d82ff;
#   color: #f1f1f1;
# }
# #T_7b61c_row0_col7 {
#   background-color: #21deff;
#   color: #000000;
# }
# #T_7b61c_row1_col1, #T_7b61c_row1_col2 {
#   background-color: #38c7ff;
#   color: #000000;
# }
# #T_7b61c_row1_col3 {
#   background-color: #04fbff;
#   color: #000000;
# }
# #T_7b61c_row1_col4 {
#   background-color: #ca35ff;
#   color: #f1f1f1;
# }
# #T_7b61c_row1_col7 {
#   background-color: #39c6ff;
#   color: #000000;
# }
# #T_7b61c_row1_col8 {
#   background-color: #37c8ff;
#   color: #000000;
# }
# #T_7b61c_row2_col4 {
#   background-color: #32cdff;
#   color: #000000;
# }
# #T_7b61c_row3_col1, #T_7b61c_row3_col2, #T_7b61c_row3_col8 {
#   background-color: #07f8ff;
#   color: #000000;
# }
# #T_7b61c_row3_col3 {
#   background-color: #e41bff;
#   color: #f1f1f1;
# }
# #T_7b61c_row3_col4 {
#   background-color: #f30cff;
#   color: #f1f1f1;
# }
# #T_7b61c_row3_col6 {
#   background-color: #926dff;
#   color: #f1f1f1;
# }
# #T_7b61c_row3_col7 {
#   background-color: #2dd2ff;
#   color: #000000;
# }
# #T_7b61c_row4_col3 {
#   background-color: #2fd0ff;
#   color: #000000;
# }
# </style>
# <table id="T_7b61c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >SOURCE_KEY</th>
#       <th class="col_heading level0 col1" >DC_POWER</th>
#       <th class="col_heading level0 col2" >AC_POWER</th>
#       <th class="col_heading level0 col3" >DAILY_YIELD</th>
#       <th class="col_heading level0 col4" >TOTAL_YIELD</th>
#       <th class="col_heading level0 col5" >DATE_TIME</th>
#       <th class="col_heading level0 col6" >AMBIENT_TEMPERATURE</th>
#       <th class="col_heading level0 col7" >MODULE_TEMPERATURE</th>
#       <th class="col_heading level0 col8" >IRRADIATION</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b61c_level0_row0" class="row_heading level0 row0" >28745</th>
#       <td id="T_7b61c_row0_col0" class="data row0 col0" >VHMLBKoKgIrUVDU</td>
#       <td id="T_7b61c_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_7b61c_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_7b61c_row0_col3" class="data row0 col3" >8172.000000</td>
#       <td id="T_7b61c_row0_col4" class="data row0 col4" >7321059.000000</td>
#       <td id="T_7b61c_row0_col5" class="data row0 col5" >2020-05-29 22:15:00</td>
#       <td id="T_7b61c_row0_col6" class="data row0 col6" >24.670178</td>
#       <td id="T_7b61c_row0_col7" class="data row0 col7" >23.417525</td>
#       <td id="T_7b61c_row0_col8" class="data row0 col8" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7b61c_level0_row1" class="row_heading level0 row1" >27494</th>
#       <td id="T_7b61c_row1_col0" class="data row1 col0" >3PZuoBAID5Wc2HD</td>
#       <td id="T_7b61c_row1_col1" class="data row1 col1" >2011.714286</td>
#       <td id="T_7b61c_row1_col2" class="data row1 col2" >197.185714</td>
#       <td id="T_7b61c_row1_col3" class="data row1 col3" >141.857143</td>
#       <td id="T_7b61c_row1_col4" class="data row1 col4" >7094120.857000</td>
#       <td id="T_7b61c_row1_col5" class="data row1 col5" >2020-05-29 07:15:00</td>
#       <td id="T_7b61c_row1_col6" class="data row1 col6" >21.808195</td>
#       <td id="T_7b61c_row1_col7" class="data row1 col7" >26.070054</td>
#       <td id="T_7b61c_row1_col8" class="data row1 col8" >0.133901</td>
#     </tr>
#     <tr>
#       <th id="T_7b61c_level0_row2" class="row_heading level0 row2" >35384</th>
#       <td id="T_7b61c_row2_col0" class="data row2 col0" >1BY6WEcLGh8j5v7</td>
#       <td id="T_7b61c_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_7b61c_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_7b61c_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_7b61c_row2_col4" class="data row2 col4" >6455679.000000</td>
#       <td id="T_7b61c_row2_col5" class="data row2 col5" >2020-06-13 02:30:00</td>
#       <td id="T_7b61c_row2_col6" class="data row2 col6" >21.824768</td>
#       <td id="T_7b61c_row2_col7" class="data row2 col7" >19.722699</td>
#       <td id="T_7b61c_row2_col8" class="data row2 col8" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7b61c_level0_row3" class="row_heading level0 row3" >38899</th>
#       <td id="T_7b61c_row3_col0" class="data row3 col0" >uHbuxQJl8lW7ozc</td>
#       <td id="T_7b61c_row3_col1" class="data row3 col1" >253.625000</td>
#       <td id="T_7b61c_row3_col2" class="data row3 col2" >24.462500</td>
#       <td id="T_7b61c_row3_col3" class="data row3 col3" >7301.500000</td>
#       <td id="T_7b61c_row3_col4" class="data row3 col4" >7267832.500000</td>
#       <td id="T_7b61c_row3_col5" class="data row3 col5" >2020-06-14 18:15:00</td>
#       <td id="T_7b61c_row3_col6" class="data row3 col6" >25.136102</td>
#       <td id="T_7b61c_row3_col7" class="data row3 col7" >24.723273</td>
#       <td id="T_7b61c_row3_col8" class="data row3 col8" >0.019034</td>
#     </tr>
#     <tr>
#       <th id="T_7b61c_level0_row4" class="row_heading level0 row4" >15875</th>
#       <td id="T_7b61c_row4_col0" class="data row4 col0" >1IF53ai7Xc0U56Y</td>
#       <td id="T_7b61c_row4_col1" class="data row4 col1" >9079.750000</td>
#       <td id="T_7b61c_row4_col2" class="data row4 col2" >888.175000</td>
#       <td id="T_7b61c_row4_col3" class="data row4 col3" >1527.375000</td>
#       <td id="T_7b61c_row4_col4" class="data row4 col4" >6242061.375000</td>
#       <td id="T_7b61c_row4_col5" class="data row4 col5" >2020-05-23 09:30:00</td>
#       <td id="T_7b61c_row4_col6" class="data row4 col6" >27.643038</td>
#       <td id="T_7b61c_row4_col7" class="data row4 col7" >47.786619</td>
#       <td id="T_7b61c_row4_col8" class="data row4 col8" >0.617463</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Adding separate time and date columns

# %%
# adding separate time and date columns
df_solar["DATE"] = pd.to_datetime(df_solar["DATE_TIME"]).dt.date
df_solar["TIME"] = pd.to_datetime(df_solar["DATE_TIME"]).dt.time
df_solar['DAY'] = pd.to_datetime(df_solar['DATE_TIME']).dt.day
df_solar['MONTH'] = pd.to_datetime(df_solar['DATE_TIME']).dt.month
df_solar['WEEK'] = pd.to_datetime(df_solar['DATE_TIME']).dt.week


# add hours and minutes for ml models
df_solar['HOURS'] = pd.to_datetime(df_solar['TIME'],format='%H:%M:%S').dt.hour
df_solar['MINUTES'] = pd.to_datetime(df_solar['TIME'],format='%H:%M:%S').dt.minute
df_solar['TOTAL MINUTES PASS'] = df_solar['MINUTES'] + df_solar['HOURS']*60

# add date as string column
df_solar["DATE_STRING"] = df_solar["DATE"].astype(str) # add column with date as string
df_solar["HOURS"] = df_solar["HOURS"].astype(str)
df_solar["TIME"] = df_solar["TIME"].astype(str)

df_solar.head(2)
# Out:
#         SOURCE_KEY  DC_POWER  AC_POWER  DAILY_YIELD  TOTAL_YIELD  DATE_TIME  \
# 0  1BY6WEcLGh8j5v7       0.0       0.0          0.0    6259559.0 2020-05-15
# 1  1IF53ai7Xc0U56Y       0.0       0.0          0.0    6183645.0 2020-05-15
#
#    AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION        DATE      TIME  \
# 0            25.184316           22.857507          0.0  2020-05-15  00:00:00
# 1            25.184316           22.857507          0.0  2020-05-15  00:00:00
#
#    DAY  MONTH  WEEK HOURS  MINUTES  TOTAL MINUTES PASS DATE_STRING
# 0   15      5    20     0        0                   0  2020-05-15
# 1   15      5    20     0        0                   0  2020-05-15

# %%
df_solar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45680 entries, 0 to 45679
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SOURCE_KEY           45680 non-null  object
#  1   DC_POWER             45680 non-null  float64
#  2   AC_POWER             45680 non-null  float64
#  3   DAILY_YIELD          45680 non-null  float64
#  4   TOTAL_YIELD          45680 non-null  float64
#  5   DATE_TIME            45680 non-null  datetime64[ns]
#  6   AMBIENT_TEMPERATURE  45680 non-null  float64
#  7   MODULE_TEMPERATURE   45680 non-null  float64
#  8   IRRADIATION          45680 non-null  float64
#  9   DATE                 45680 non-null  object
#  10  TIME                 45680 non-null  object
#  11  DAY                  45680 non-null  int64
#  12  MONTH                45680 non-null  int64
#  13  WEEK                 45680 non-null  int64
#  14  HOURS                45680 non-null  object
#  15  MINUTES              45680 non-null  int64
#  16  TOTAL MINUTES PASS   45680 non-null  int64
#  17  DATE_STRING          45680 non-null  object
# dtypes: datetime64[ns](1), float64(7), int64(5), object(5)
# memory usage: 6.6+ MB

# %% [markdown]
# # finding null values

# %%
df_solar.isnull().sum()
# Out:
# SOURCE_KEY             0
# DC_POWER               0
# AC_POWER               0
# DAILY_YIELD            0
# TOTAL_YIELD            0
# DATE_TIME              0
# AMBIENT_TEMPERATURE    0
# MODULE_TEMPERATURE     0
# IRRADIATION            0
# DATE                   0
# TIME                   0
# DAY                    0
# MONTH                  0
# WEEK                   0
# HOURS                  0
# MINUTES                0
# TOTAL MINUTES PASS     0
# DATE_STRING            0
# dtype: int64

# %% [markdown]
# # There is no Missing Values in the dataset

# %%
df_solar.describe().style.background_gradient(cmap='rainbow')
# Out:
# <style type="text/css">
# #T_ecf6c_row0_col0, #T_ecf6c_row0_col1, #T_ecf6c_row0_col2, #T_ecf6c_row0_col4, #T_ecf6c_row0_col5, #T_ecf6c_row0_col6, #T_ecf6c_row0_col7, #T_ecf6c_row0_col8, #T_ecf6c_row0_col9, #T_ecf6c_row0_col10, #T_ecf6c_row0_col11, #T_ecf6c_row7_col3 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_ecf6c_row0_col3, #T_ecf6c_row1_col4, #T_ecf6c_row1_col5, #T_ecf6c_row1_col6, #T_ecf6c_row1_col7, #T_ecf6c_row1_col8, #T_ecf6c_row1_col9, #T_ecf6c_row1_col10, #T_ecf6c_row2_col4, #T_ecf6c_row2_col5, #T_ecf6c_row2_col6, #T_ecf6c_row2_col7, #T_ecf6c_row2_col8, #T_ecf6c_row2_col9, #T_ecf6c_row2_col10, #T_ecf6c_row3_col0, #T_ecf6c_row3_col1, #T_ecf6c_row3_col2, #T_ecf6c_row3_col4, #T_ecf6c_row3_col5, #T_ecf6c_row3_col6, #T_ecf6c_row3_col7, #T_ecf6c_row3_col8, #T_ecf6c_row3_col9, #T_ecf6c_row3_col10, #T_ecf6c_row3_col11, #T_ecf6c_row4_col0, #T_ecf6c_row4_col1, #T_ecf6c_row4_col2, #T_ecf6c_row4_col4, #T_ecf6c_row4_col5, #T_ecf6c_row4_col6, #T_ecf6c_row4_col7, #T_ecf6c_row4_col8, #T_ecf6c_row4_col9, #T_ecf6c_row4_col10, #T_ecf6c_row5_col1, #T_ecf6c_row5_col4, #T_ecf6c_row5_col5, #T_ecf6c_row5_col6, #T_ecf6c_row5_col7, #T_ecf6c_row5_col8, #T_ecf6c_row5_col9, #T_ecf6c_row5_col10, #T_ecf6c_row6_col4, #T_ecf6c_row6_col5, #T_ecf6c_row6_col6, #T_ecf6c_row6_col7, #T_ecf6c_row6_col8, #T_ecf6c_row6_col9, #T_ecf6c_row6_col10, #T_ecf6c_row7_col4, #T_ecf6c_row7_col5, #T_ecf6c_row7_col6, #T_ecf6c_row7_col7, #T_ecf6c_row7_col8, #T_ecf6c_row7_col9, #T_ecf6c_row7_col10 {
#   background-color: #8000ff;
#   color: #f1f1f1;
# }
# #T_ecf6c_row1_col0, #T_ecf6c_row2_col2 {
#   background-color: #5e35fe;
#   color: #f1f1f1;
# }
# #T_ecf6c_row1_col1 {
#   background-color: #7e03ff;
#   color: #f1f1f1;
# }
# #T_ecf6c_row1_col2 {
#   background-color: #5c38fd;
#   color: #f1f1f1;
# }
# #T_ecf6c_row1_col3 {
#   background-color: #ff592d;
#   color: #f1f1f1;
# }
# #T_ecf6c_row1_col11, #T_ecf6c_row5_col11 {
#   background-color: #780dff;
#   color: #f1f1f1;
# }
# #T_ecf6c_row2_col0 {
#   background-color: #5444fd;
#   color: #f1f1f1;
# }
# #T_ecf6c_row2_col1, #T_ecf6c_row2_col11, #T_ecf6c_row4_col11, #T_ecf6c_row5_col0 {
#   background-color: #7c06ff;
#   color: #f1f1f1;
# }
# #T_ecf6c_row2_col3 {
#   background-color: #6826fe;
#   color: #f1f1f1;
# }
# #T_ecf6c_row3_col3 {
#   background-color: #ff9d53;
#   color: #000000;
# }
# #T_ecf6c_row4_col3 {
#   background-color: #ff8143;
#   color: #f1f1f1;
# }
# #T_ecf6c_row5_col2 {
#   background-color: #642cfe;
#   color: #f1f1f1;
# }
# #T_ecf6c_row5_col3 {
#   background-color: #ff4724;
#   color: #f1f1f1;
# }
# #T_ecf6c_row6_col0 {
#   background-color: #386df9;
#   color: #f1f1f1;
# }
# #T_ecf6c_row6_col1 {
#   background-color: #7a09ff;
#   color: #f1f1f1;
# }
# #T_ecf6c_row6_col2 {
#   background-color: #396bf9;
#   color: #f1f1f1;
# }
# #T_ecf6c_row6_col3 {
#   background-color: #ff3b1e;
#   color: #f1f1f1;
# }
# #T_ecf6c_row6_col11 {
#   background-color: #7610ff;
#   color: #f1f1f1;
# }
# #T_ecf6c_row7_col0 {
#   background-color: #22d6e0;
#   color: #000000;
# }
# #T_ecf6c_row7_col1, #T_ecf6c_row7_col11 {
#   background-color: #7216ff;
#   color: #f1f1f1;
# }
# #T_ecf6c_row7_col2 {
#   background-color: #1996f3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ecf6c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >DC_POWER</th>
#       <th class="col_heading level0 col1" >AC_POWER</th>
#       <th class="col_heading level0 col2" >DAILY_YIELD</th>
#       <th class="col_heading level0 col3" >TOTAL_YIELD</th>
#       <th class="col_heading level0 col4" >AMBIENT_TEMPERATURE</th>
#       <th class="col_heading level0 col5" >MODULE_TEMPERATURE</th>
#       <th class="col_heading level0 col6" >IRRADIATION</th>
#       <th class="col_heading level0 col7" >DAY</th>
#       <th class="col_heading level0 col8" >MONTH</th>
#       <th class="col_heading level0 col9" >WEEK</th>
#       <th class="col_heading level0 col10" >MINUTES</th>
#       <th class="col_heading level0 col11" >TOTAL MINUTES PASS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ecf6c_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_ecf6c_row0_col0" class="data row0 col0" >45680.000000</td>
#       <td id="T_ecf6c_row0_col1" class="data row0 col1" >45680.000000</td>
#       <td id="T_ecf6c_row0_col2" class="data row0 col2" >45680.000000</td>
#       <td id="T_ecf6c_row0_col3" class="data row0 col3" >45680.000000</td>
#       <td id="T_ecf6c_row0_col4" class="data row0 col4" >45680.000000</td>
#       <td id="T_ecf6c_row0_col5" class="data row0 col5" >45680.000000</td>
#       <td id="T_ecf6c_row0_col6" class="data row0 col6" >45680.000000</td>
#       <td id="T_ecf6c_row0_col7" class="data row0 col7" >45680.000000</td>
#       <td id="T_ecf6c_row0_col8" class="data row0 col8" >45680.000000</td>
#       <td id="T_ecf6c_row0_col9" class="data row0 col9" >45680.000000</td>
#       <td id="T_ecf6c_row0_col10" class="data row0 col10" >45680.000000</td>
#       <td id="T_ecf6c_row0_col11" class="data row0 col11" >45680.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ecf6c_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_ecf6c_row1_col0" class="data row1 col0" >3197.175971</td>
#       <td id="T_ecf6c_row1_col1" class="data row1 col1" >312.652679</td>
#       <td id="T_ecf6c_row1_col2" class="data row1 col2" >3313.146538</td>
#       <td id="T_ecf6c_row1_col3" class="data row1 col3" >6957007.021147</td>
#       <td id="T_ecf6c_row1_col4" class="data row1 col4" >25.917168</td>
#       <td id="T_ecf6c_row1_col5" class="data row1 col5" >31.877975</td>
#       <td id="T_ecf6c_row1_col6" class="data row1 col6" >0.236834</td>
#       <td id="T_ecf6c_row1_col7" class="data row1 col7" >20.414317</td>
#       <td id="T_ecf6c_row1_col8" class="data row1 col8" >5.275131</td>
#       <td id="T_ecf6c_row1_col9" class="data row1 col9" >22.090543</td>
#       <td id="T_ecf6c_row1_col10" class="data row1 col10" >22.484895</td>
#       <td id="T_ecf6c_row1_col11" class="data row1 col11" >719.701182</td>
#     </tr>
#     <tr>
#       <th id="T_ecf6c_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_ecf6c_row2_col0" class="data row2 col0" >4080.448523</td>
#       <td id="T_ecf6c_row2_col1" class="data row2 col1" >398.668968</td>
#       <td id="T_ecf6c_row2_col2" class="data row2 col2" >3156.100252</td>
#       <td id="T_ecf6c_row2_col3" class="data row2 col3" >417238.643557</td>
#       <td id="T_ecf6c_row2_col4" class="data row2 col4" >3.556550</td>
#       <td id="T_ecf6c_row2_col5" class="data row2 col5" >12.638448</td>
#       <td id="T_ecf6c_row2_col6" class="data row2 col6" >0.306316</td>
#       <td id="T_ecf6c_row2_col7" class="data row2 col7" >6.258661</td>
#       <td id="T_ecf6c_row2_col8" class="data row2 col8" >0.446585</td>
#       <td id="T_ecf6c_row2_col9" class="data row2 col9" >1.568935</td>
#       <td id="T_ecf6c_row2_col10" class="data row2 col10" >16.777147</td>
#       <td id="T_ecf6c_row2_col11" class="data row2 col11" >410.155042</td>
#     </tr>
#     <tr>
#       <th id="T_ecf6c_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_ecf6c_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_ecf6c_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_ecf6c_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_ecf6c_row3_col3" class="data row3 col3" >6183645.000000</td>
#       <td id="T_ecf6c_row3_col4" class="data row3 col4" >20.398505</td>
#       <td id="T_ecf6c_row3_col5" class="data row3 col5" >18.140415</td>
#       <td id="T_ecf6c_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_ecf6c_row3_col7" class="data row3 col7" >6.000000</td>
#       <td id="T_ecf6c_row3_col8" class="data row3 col8" >5.000000</td>
#       <td id="T_ecf6c_row3_col9" class="data row3 col9" >20.000000</td>
#       <td id="T_ecf6c_row3_col10" class="data row3 col10" >0.000000</td>
#       <td id="T_ecf6c_row3_col11" class="data row3 col11" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ecf6c_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_ecf6c_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_ecf6c_row4_col1" class=

# %% [markdown]
# # Converting 'SOURCE_KEY' from categorical form to numerical form

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df_solar['SOURCE_KEY_NUMBER'] = encoder.fit_transform(df_solar['SOURCE_KEY'])
df_solar.head()
# Out:
#         SOURCE_KEY  DC_POWER  AC_POWER  DAILY_YIELD  TOTAL_YIELD  DATE_TIME  \
# 0  1BY6WEcLGh8j5v7       0.0       0.0          0.0    6259559.0 2020-05-15
# 1  1IF53ai7Xc0U56Y       0.0       0.0          0.0    6183645.0 2020-05-15
# 2  3PZuoBAID5Wc2HD       0.0       0.0          0.0    6987759.0 2020-05-15
# 3  7JYdWkrLSPkdwr4       0.0       0.0          0.0    7602960.0 2020-05-15
# 4  McdE0feGgRqW7Ca       0.0       0.0          0.0    7158964.0 2020-05-15
#
#    AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION        DATE      TIME  \
# 0            25.184316           22.857507          0.0  2020-05-15  00:00:00
# 1            25.184316           22.857507          0.0  2020-05-15  00:00:00
# 2            25.184316           22.857507          0.0  2020-05-15  00:00:00
# 3            25.184316           22.857507          0.0  2020-05-15  00:00:00
# 4            25.184316           22.857507          0.0  2020-05-15  00:00:00
#
#    DAY  MONTH  WEEK HOURS  MINUTES  TOTAL MINUTES PASS DATE_STRING  \
# 0   15      5    20     0        0                   0  2020-05-15
# 1   15      5    20     0        0                   0  2020-05-15
# 2   15      5    20     0        0                   0  2020-05-15
# 3   15      5    20     0        0                   0  2020-05-15
# 4   15      5    20     0        0                   0  2020-05-15
#
#    SOURCE_KEY_NUMBER
# 0                  0
# 1                  1
# 2                  2
# 3                  3
# 4                  4

# %% [markdown]
# # Data Visualization

# %%
sns.displot(data=df_solar, x="AMBIENT_TEMPERATURE", kde=True, bins = 100,color = "red", facecolor = "#3F7F7F",height = 5, aspect = 3.5);

# %%
df_solar['DATE'].nunique()
# Out:
# 23

# %% [markdown]
# # The data of solar power generation is of 23 days

# %% [markdown]
# # Faults & Abnormalities detection in solar power plant generation

# %% [markdown]
# # Multiple Plotting of DC_POWER generation on per day basis.

# %%
solar_dc = df_solar.pivot_table(values='DC_POWER', index='TIME', columns='DATE')

def Daywise_plot(data= None, row = None, col = None, title='DC Power'):
    cols = data.columns # take all column
    gp = plt.figure(figsize=(20,40)) 
    
    gp.subplots_adjust(wspace=0.2, hspace=0.5)
    for i in range(1, len(cols)+1):
        ax = gp.add_subplot(row,col, i)
        data[cols[i-1]].plot(ax=ax, color='blue')
        ax.set_title('{} {}'.format(title, cols[i-1]),color='red')
        
Daywise_plot(data=solar_dc, row=12, col=3)

# %% [markdown]
# #
# above per day DC_POWER generation graph shows that there is a some fluctuation in the Solar power generation.
#
# Less Fluctuation in DC_POWER generation is observed in the below mentioned days.
#
#         2020-05-15
#         2020-05-18
#         2020-05-22
#         2020-05-23
#         2020-05-24
#         2020-05-25
#         2020-05-26
#
# High Fluctuation in DC_POWER generation is observed in the below mentioned days.
#
#         2020-05-19
#         2020-05-28
#         2020-05-29
#         2020-06-02
#         2020-06-03
#         2020-06-04
#         2020-06-13
#         2020-06-14
#         2020-06-17
#
# Very High Fluctuation & Reduction in DC_POWER generation is observed in in the below mentioned days.
#
#         2020-06-03
#         2020-06-11
#         2020-06-12
#         2020-06-15
#
# Note: Reason for very high Fluctuation & Reduction in DC_POWER generation is due to fault in the system or may be fluctuation in weather or due to clouds etc. which need to be analyse further

# %%
daily_dc = df_solar.groupby('DATE')['DC_POWER'].agg('sum')

ax = daily_dc.sort_values(ascending=False).plot.bar(figsize=(17,5), legend=True,color='darkred')
plt.title('Daily DC Power')
plt.show()

# %% [markdown]
# # Form the per day DC_POWER generation graph we can find the average power generation per day.
#
#     Highest average DC_POWER Generation is on: 2020-05-25
#
#     Lowest average DC_POWER Generation is on : 2020-05-18

# %% [markdown]
# # NOTE: This Large variation in the DC_POWER generation is due to the fault in the system or due to weather change, which needs to study further. But from this bar plot we find the day on which there is highest DC_POWER is generated and the day with the lowest DC_POWER generated.

# %% [markdown]
# # Multiple Plotting of IRRADIATION generation on per day basis.

# %%
solar_irradiation = df_solar.pivot_table(values='IRRADIATION', index='TIME', columns='DATE')

def Daywise_plot(data= None, row = None, col = None, title='IRRADIATION'):
    cols = data.columns # take all column
    gp = plt.figure(figsize=(20,40)) 
    
    gp.subplots_adjust(wspace=0.2, hspace=0.5)
    for i in range(1, len(cols)+1):
        ax = gp.add_subplot(row,col, i)
        data[cols[i-1]].plot(ax=ax, color='red')
        ax.set_title('{} {}'.format(title, cols[i-1]),color='blue')
        
Daywise_plot(data=solar_irradiation, row=12, col=3)

# %% [markdown]
# # IRRADIATION graph pattern is looking very similar to the corresponding DC_POWER generation on per day basis.
#
#     In solar power plant DC_POWER or Output power mostly depends on the IRRADIATION received from the sun .Or it is not wrong to say that generation is directly proportional to IRRADIATION.

# %%
daily_irradiation = df_solar.groupby('DATE')['IRRADIATION'].agg('sum')

daily_irradiation.sort_values(ascending=False).plot.bar(figsize=(17,5), legend=True,color='red')
plt.title('IRRADIATION')
plt.show()

# %% [markdown]
# # Form the per day IRRADIATION graph we can find the average IRREDIATION per day.
#
#     Highest average IRRADIATION is on: 2020-05-25
#
#     Lowest average IRRADIATION is on : 2020-05-18

# %%
solar_ambiant_temp = df_solar.pivot_table(values='AMBIENT_TEMPERATURE', index='TIME', columns='DATE')

def Daywise_plot(data= None, row = None, col = None, title='AMBIENT_TEMPERATURE'):
    cols = data.columns # take all column
    gp = plt.figure(figsize=(20,40)) 
    
    gp.subplots_adjust(wspace=0.2, hspace=0.5)
    for i in range(1, len(cols)+1):
        ax = gp.add_subplot(row,col, i)
        data[cols[i-1]].plot(ax=ax, color='darkgreen')
        ax.set_title('{} {}'.format(title, cols[i-1]),color='darkblue')
        
Daywise_plot(data=solar_ambiant_temp, row=12, col=3)

# %%
daily_ambient_temp = df_solar.groupby('DATE')['AMBIENT_TEMPERATURE'].agg('sum')

daily_ambient_temp.sort_values(ascending=False).plot.bar(figsize=(17,5), legend=True,color='darkred')
plt.title('AMBIENT_TEMPERATURE')
plt.show()

# %% [markdown]
# # Comparision between Best and Worst Power generation

# %% [markdown]
# Highest average DC_POWER is generated on "2020-05-25"

# %%
plt.figure(figsize=(16,16))

date=["2020-05-25"]

plt.subplot(411)
sns.lineplot(df_solar[df_solar["DATE_STRING"].isin(date)].DATE_TIME, df_solar[df_solar["DATE_STRING"].isin(date)].DC_POWER, label="DC_Power_Best",color='green');
plt.title("DC Power Generation: {}" .format(date[0]))

plt.subplot(412)
sns.lineplot(df_solar[df_solar["DATE_STRING"].isin(date)].DATE_TIME, df_solar[df_solar["DATE_STRING"].isin(date)].IRRADIATION, label="Irridation_Best",color='green');
plt.title("Irradiation : {}" .format(date[0]))

plt.subplot(413)
sns.lineplot(df_solar[df_solar["DATE_STRING"].isin(date)].DATE_TIME, df_solar[df_solar["DATE_STRING"].isin(date)].AMBIENT_TEMPERATURE, label="Ambient_Temperature_Best",color='green');
sns.lineplot(df_solar[df_solar["DATE_STRING"].isin(date)].DATE_TIME, df_solar[df_solar["DATE_STRING"].isin(date)].MODULE_TEMPERATURE, label="Module_Temperature_Best",color='blue');
plt.title("Module Temperature & Ambient Temperature: {}" .format(date[0]));

plt.tight_layout()
plt.show()

# %% [markdown]
# NOTE: Both DC_POWER graph and IRRADIATION graph is almost looking like an ideal graph. Weather is also looking good, and there is no cloud is in the sky because there is very less variation in IRRADIATION and temperature of the solar panel and ambient temperature.

# %% [markdown]
# Lowest average DC_POWER is generated on "2020-06-18"

# %%
date=["2020-05-18"]
plt.figure(figsize=(16,16))

plt.subplot(411)
sns.lineplot(df_solar[df_solar["DATE_STRING"].isin(date)].DATE_TIME, df_solar[df_solar["DATE_STRING"].isin(date)].DC_POWER, label="DC_Power_Worst",color='red');
plt.title("DC Power Generation: {}" .format(date[0]))

plt.subplot(412)
sns.lineplot(df_solar[df_solar["DATE_STRING"].isin(date)].DATE_TIME, df_solar[df_solar["DATE_STRING"].isin(date)].IRRADIATION, label="Irridation_Worst",color='red');
plt.title("Irradiation : {}" .format(date[0]))

plt.subplot(413)
sns.lineplot(df_solar[df_solar["DATE_STRING"].isin(date)].DATE_TIME, df_solar[df_solar["DATE_STRING"].isin(date)].AMBIENT_TEMPERATURE, label="Ambient_Temperature_Worst",color='red');
sns.lineplot(df_solar[df_solar["DATE_STRING"].isin(date)].DATE_TIME, df_solar[df_solar["DATE_STRING"].isin(date)].MODULE_TEMPERATURE, label="Module_Temperature_Worst",color='blue');
plt.title("Module Temperature & Ambient Temperature: {}" .format(date[0]));

plt.tight_layout()
plt.show()

# %% [markdown]
# #The possible reason for this reduction is due to may be heavy rain and heavily clouded sky and bad weather. There is almost very less possibility of any fault in the system

# %%
sns.lmplot(y="DC_POWER",x="DAILY_YIELD",hue="SOURCE_KEY",col="SOURCE_KEY",height=3,col_wrap=4,data=df_solar,fit_reg=True);

# %% [markdown]
# Solar Power Plant Inverter Efficiency Calculation

# %%
solar_dc_power = df_solar[df_solar['DC_POWER'] > 0]['DC_POWER'].values
solar_ac_power = df_solar[df_solar['AC_POWER'] > 0]['AC_POWER'].values

# %%
solar_dc_power.max()
# Out:
# 14471.125

# %%
solar_ac_power.max()
# Out:
# 1410.95

# %%
solar_plant_eff = (np.max(solar_ac_power)/np.max(solar_dc_power ))*100
print(f"Power conversion Efficiency ratio AC/DC of Solar Power Plant:  {solar_plant_eff:0.3f} %")
# Out:
# Power conversion Efficiency ratio AC/DC of Solar Power Plant:  9.750 %

# %%
AC_list=[]
for i in df_solar['AC_POWER']:
    if i>0:
        AC_list.append(i)
AC_list
#AC_list.sort()
#AC_list.reverse()
len(AC_list)
# Out:
# 24620

# %%
#Here we take all nonzero DC values and plot them on histogram
DC_list=[]
for i in df_solar['DC_POWER']:
    if i>0:
        DC_list.append(i)
DC_list
DC_list.sort()
DC_list.reverse()
len(DC_list)
# Out:
# 24620

# %%
plt.figure(figsize=(16,8))
AC_list.sort()
DC_list.sort()
eff = [i/j for i,j in zip(AC_list,DC_list)]

plt.plot(AC_list,eff,color='darkgreen')
plt.xlabel('Output power in kW')
plt.ylabel('Efficiency AC/DC')
plt.title('Output Power vs Efficiency');

# %% [markdown]
# # Solar Power Prediction using different ML techniques

# %%
df2 = df_solar.copy()
X = df2[['DAILY_YIELD','TOTAL_YIELD','AMBIENT_TEMPERATURE','MODULE_TEMPERATURE','IRRADIATION','DC_POWER']]
y = df2['AC_POWER']

# %% [markdown]
# # if required you can check the values in X and y by passing the command X.head() and y.head()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.2,random_state=21)

# %% [markdown]
# ## 1. LinearRegression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

lr_clf = LinearRegression()
lr_clf.fit(X_train,y_train)
score_lr = 100*lr_clf.score(X_test,y_test)
print(f'LR Model score = {score_lr:4.4f}%')
# Out:
# LR Model score = 99.9994%

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred_lr = lr.predict(X_test)
R2_Score_lr = round(r2_score(y_pred_lr,y_test) * 100, 2)

print("R2 Score : ",R2_Score_lr,"%")
# Out:
# R2 Score :  100.0 %

# %% [markdown]
# # 2. Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor()
rfr.fit(X_train,y_train)
y_pred_rfr = lr.predict(X_test)
R2_Score_rfr = round(r2_score(y_pred_rfr,y_test) * 100, 2)

print("R2 Score : ",R2_Score_rfr,"%")
# Out:
# R2 Score :  100.0 %

# %% [markdown]
# # 3. Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor()
dtr.fit(X_train,y_train)

y_pred_dtr = lr.predict(X_test)
R2_Score_dtr = round(r2_score(y_pred_dtr,y_test) * 100, 2)

print("R2 Score : ",R2_Score_dtr,"%")
# Out:
# R2 Score :  100.0 %

# %% [markdown]
# # 12. Result Prediction

# %%
forecast_prediction = rfr.predict(X_test)
print(forecast_prediction)
# Out:
# [  0.         186.23442857 970.58608928 ...   0.           0.
#  363.03957143]

# %%
cross_check = pd.DataFrame({'Actual' : y_test , 'Predicted' : forecast_prediction})
cross_check.head()
# Out:
#            Actual   Predicted
# 39704    0.000000    0.000000
# 16578  186.325000  186.234429
# 38467  971.014286  970.586089
# 19471    0.000000    0.000000
# 21836    0.000000    0.000000

# %%
cross_check['Error'] = cross_check['Actual'] - cross_check['Predicted']
cross_check.head()
# Out:
#            Actual   Predicted     Error
# 39704    0.000000    0.000000  0.000000
# 16578  186.325000  186.234429  0.090571
# 38467  971.014286  970.586089  0.428196
# 19471    0.000000    0.000000  0.000000
# 21836    0.000000    0.000000  0.000000

# %%
cross_check_final  = cross_check[cross_check['Error'] <= 20]
cross_check_final.sample(25).style.background_gradient(
        cmap='coolwarm').set_properties(**{
            'font-family': 'Times',
            'color': 'LigntGreen',
            'font-size': '13px'
        })
# Out:
# <style type="text/css">
# #T_4c072_row0_col0, #T_4c072_row0_col1 {
#   background-color: #de614d;
#   color: #f1f1f1;
#   font-family: Times;
#   color: LigntGreen;
#   font-size: 13px;
# }
# #T_4c072_row0_col2, #T_4c072_row22_col0, #T_4c072_row22_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
#   font-family: Times;
#   color: LigntGreen;
#   font-size: 13px;
# }
# #T_4c072_row1_col0, #T_4c072_row1_col1, #T_4c072_row2_col0, #T_4c072_row2_col1, #T_4c072_row3_col0, #T_4c072_row3_col1, #T_4c072_row4_col0, #T_4c072_row4_col1, #T_4c072_row8_col0, #T_4c072_row8_col1, #T_4c072_row11_col0, #T_4c072_row11_col1, #T_4c072_row13_col0, #T_4c072_row13_col1, #T_4c072_row15_col0, #T_4c072_row15_col1, #T_4c072_row16_col0, #T_4c072_row16_col1, #T_4c072_row17_col0, #T_4c072_row17_col1, #T_4c072_row18_col0, #T_4c072_row18_col1, #T_4c072_row19_col0, #T_4c072_row19_col1, #T_4c072_row23_col0, #T_4c072_row23_col1, #T_4c072_row24_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
#   font-family: Times;
#   color: LigntGreen;
#   font-size: 13px;
# }
# #T_4c072_row1_col2, #T_4c072_row2_col2, #T_4c072_row3_col2, #T_4c072_row4_col2, #T_4c072_row8_col2, #T_4c072_row11_col2, #T_4c072_row13_col2, #T_4c072_row15_col2, #T_4c072_row16_col2, #T_4c072_row17_col2, #T_4c072_row18_col2, #T_4c072_row19_col2, #T_4c072_row23_col2 {
#   background-color: #f6a586;
#   color: #000000;
#   font-family: Times;
#   color: LigntGreen;
#   font-size: 13px;
# }
# #T_4c072_row5_col0, #T_4c072_row5_col1, #T_4c072_row14_col1 {
#   background-color: #cd423b;
#   color: #f1f1f1;
#   font-family: Times;
#   color: LigntGreen;
#   font-size: 13px;
# }
# #T_4c072_row5_col2 {
#   background-color: #f5c1a9;
#   color: #000000;
#   font-family: Times;
#   color: LigntGreen;
#   font-size: 13px;
# }
# #T_4c072_row6_col0, #T_4c072_row6_col1 {
#   background-color: #c0282f;
#   color: #f1f1f1;
#   font-family: Times;
#   color: LigntGreen;
#   font-size: 13px;
# }
# #T_4c072_row6_col2 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
#   font-family: Times;
#   color: LigntGreen;
#   font-size: 13px;
# }
# #T_4c072_row7_col0, #T_4c072_row7_col1, #T_4c072_row10_col2 {
#   background-color: #f7ac8e;
#   color: #000000;
#   font-family: Times;
#   color: LigntGreen;
#   font-size: 13px;
# }
# #T_4c072_row7_col2 {
#   background-color: #bed2f6;
#   color: #000000;
#   font-family: Times;
#   color: LigntGreen;
#   font-size: 13px;
# }
# #T_4c072_row9_col0, #T_4c072_row9_col1 {
#   background-color: #8badfd;
#   color: #000000;
#   font-family: Times;
#   color: LigntGreen;
#   font-size: 13px;
# }
# #T_4c072_row9_col2 {
#   background-color: #e57058;
#   color: #f1f1f1;
#   font-family: Times;
#   color: LigntGreen;
#   font-size: 13px;
# }
# #T_4c072_row10_col0, #T_4c072_row10_col1 {
#   background-color: #cdd9ec;
#   color: #000000;
#   font-family: Times;
#   color: LigntGreen;
#   font-size: 13px;
# }
# #T_4c072_row12_col0, #T_4c072_row12_col1 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
#   font-family: Times;
#   color: LigntGreen;
#   font-size: 13px;
# }
# #T_4c072_row12_col2 {
#   background-color: #f29274;
#   color: #f1f1f1;
#   font-family: Times;
#   color: LigntGreen;
#   font-size: 13px;
# }
# #T_4c072_row14_col0 {
#   background-color: #cf453c;
#   color: #f1f1f1;
#   font-family: Times;
#   color: LigntGreen;
#   font-size: 13px;
# }
# #T_4c072_row14_col2 {
#   background-color: #a2c1ff;
#   color: #000000;
#   font-family: Times;
#   color: LigntGreen;
#   font-size: 13px;
# }
# #T_4c072_row20_col0, #T_4c072_row20_col1 {
#   background-color: #efcfbf;
#   color: #000000;
#   font-family: Times;
#   color: LigntGreen;
#   font-size: 13px;
# }
# #T_4c072_row20_col2 {
#   background-color: #f1cdba;
#   color: #000000;
#   font-family: Times;
#   color: LigntGreen;
#   font-size: 13px;
# }
# #T_4c072_row21_col0, #T_4c072_row21_col1 {
#   background-color: #f0cdbb;
#   color: #000000;
#   font-family: Times;
#   color: LigntGreen;
#   font-size: 13px;
# }
# #T_4c072_row21_col2 {
#   background-color: #f7af91;
#   color: #000000;
#   font-family: Times;
#   color: LigntGreen;
#   font-size: 13px;
# }
# #T_4c072_row22_col2 {
#   background-color: #f7aa8c;
#   color: #000000;
#   font-family: Times;
#   color: LigntGreen;
#   font-size: 13px;
# }
# #T_4c072_row24_col0, #T_4c072_row24_col1 {
#   background-color: #f7bca1;
#   color: #000000;
#   font-family: Times;
#   color: LigntGreen;
#   font-size: 13px;
# }
# </style>
# <table id="T_4c072_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Actual</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#       <th class="col_heading level0 col2" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c072_level0_row0" class="row_heading level0 row0" >42428</th>
#       <td id="T_4c072_row0_col0" class="data row0 col0" >854.028571</td>
#       <td id="T_4c072_row0_col1" class="data row0 col1" >853.749857</td>
#       <td id="T_4c072_row0_col2" class="data row0 col2" >0.278714</td>
#     </tr>
#     <tr>
#       <th id="T_4c072_level0_row1" class="row_heading level0 row1" >23724</th>
#       <td id="T_4c072_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_4c072_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_4c072_row1_col2" class="data row1 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4c072_level0_row2" class="row_heading level0 row2" >6366</th>
#       <td id="T_4c072_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_4c072_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_4c072_row2_col2" class="data row2 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4c072_level0_row3" class="row_heading level0 row3" >23604</th>
#       <td id="T_4c072_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_4c072_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_4c072_row3_col2" class="data row3 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4c072_level0_row4" class="row_heading level0 row4" >6270</th>
#       <td id="T_4c072_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_4c072_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_4c072_row4_col2" class="data row4 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4c072_level0_row5" class="row_heading level0 row5" >40452</th>
#       <td id="T_4c072_row5_col0" class="data row5 col0" >909.750000</td>
#       <td id="T_4c072_row5_col1" class="data row5 col1" >909.834250</td>
#       <td id="T_4c072_row5_col2" class="data row5 col2" >-0.084250</td>
#     </tr>
#     <tr>
#       <th id="T_4c072_level0_row6" class="row_heading level0 row6" >44744</th>
#       <td id="T_4c072_row6_col0" class="data row6 col0" >947.314286</td>
#       <td id="T_4c072_row6_col1" class="data row6 col1" >947.215929</td>
#       <td id="T_4c072_row6_col2" class="data row6 col2" >0.098357</td>
#     </tr>
#     <tr>
#       <th id="T_4c072_level0_row7" class="row_heading level0 row7" >9069</th>
#       <td id="T_4c072_row7_col0" class="data row7 col0" >684.957143</td>
#       <td id="T_4c072_row7_col1" class="data row7 col1" >685.283107</td>
#       <td id="T_4c072_row7_col2" class="data row7 col2" >-0.325964</td>
#     </tr>
#     <tr>
#       <th id="T_4c072_level0_row8" class="row_heading level0 row8" >17499</th>
#       <td id="T_4c072_row8_col0" class="data row8 col0" >0.000000</td>
#       <td id="T_4c072_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_4c072_row8_col2" class="data row8 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4c072_level0_row9" class="row_heading level0 row9" >8737</th>
#       <td id="T_4c072_row9_col0" class="data row9 col0" >240.075000</td>
#       <td id="T_4c072_row9_col1" class="data row9 col1" >239.951982</td>
#       <td id="T_4c072_row9_col2" class="data row9 col2" >0.123018</td>
#     </tr>
#     <tr>
#       <th id="T_4c072_level0_row10" class="row_heading level0 row10" >5280</th>
#       <td id="T_4c072_row10_col0" class="data row10 col0" >435.400000</td>
#       <td id="T_4c072_row10_col1" class="data row10 col1" >435.418339</td>
#       <td id="T_4c072_row10_col2" class="data row10 col2" >-0.018339</td>
#     </tr>
#     <tr>
#       <th id="T_4c072_level0_row11" class="row_heading level0 row11" >13233</th>
#       <td id="T_4c072_

# %%
# Visualizing the differences between actual prices and predicted values
plt.scatter(y_test,forecast_prediction)
plt.xlabel("Prices")
plt.ylabel("Predicted prices")
plt.title("Prices vs Predicted prices")
plt.show()

# %%
df3 = cross_check.head(50)
df3.plot(kind='bar',figsize=(20,10))
plt.grid(which='major', linestyle='-', linewidth='0.5',color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5',color='black')
plt.show()
